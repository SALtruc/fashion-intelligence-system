# %% [markdown]
# # Task 2: DenseNet-121
#
# This notebook loads Notebook 1's prepared arrays and trains only DenseNet-121. Shared neural-network
# augmentation, batching, checkpointing, recovery, and evaluation live in `src/task2_utils.py`.

# %% [markdown]
# ## How to Run
#
# Run `01_task2_setup.ipynb` first. Change the settings below if needed, then run this notebook.
# It does not rerun setup or another model.

# %% [markdown]
# ## 1. Setup

# %%
# %matplotlib inline
import torch.nn as nn
from IPython.display import display

# %%
from pathlib import Path
import sys

REPO_ROOT = next((p for p in [Path.cwd(), *Path.cwd().parents]
                  if (p / "pyproject.toml").exists()), None)
if REPO_ROOT is None:
    raise FileNotFoundError("Could not find the repository root containing pyproject.toml")
sys.path.insert(0, str(REPO_ROOT))

from torchvision.models import densenet121
from src.task2_utils import (
    NeuralTrainer, ensure_task2_directories, model_checkpoint_path,
    neural_training_config, prepared_namespace, result_frame,
)
ensure_task2_directories()

# %% [markdown]
# ### 1.1 Training configuration

# %%
QUICK_RUN = False
RANDOM_STATE = 42
RESUME = False
ALLOW_CPU = False

# Editable DenseNet-121 hyperparameters. These override the shared defaults.
HYPERPARAMETERS = {
    "epochs": 30,
    "warmup_epochs": 4,
    "batch_size": 128,
    "patience": 5,

    "learning_rate": 1e-3,
    "weight_decay": 1.0e-3,

    "label_smoothing": 0.05,
    # 0.0 disables weighting; 0.5 uses square-root inverse training frequency.
    "class_weight_power": 0.0,

    "flip_probability": 0.5,
    "rotation_degrees": 12.0,
    "translate_fraction": 0.10,
    "jitter_strength": 0.05,

}

TRAINING_CONFIG = neural_training_config(
    quick_run=QUICK_RUN, random_state=RANDOM_STATE, resume=RESUME, allow_cpu=ALLOW_CPU,
)
TRAINING_CONFIG.update(HYPERPARAMETERS)
MODEL_CONFIG = {"architecture": "densenet121", "classifier_dropout": 0.40, **{
    key: value for key, value in TRAINING_CONFIG.items()
    if key not in {"resume", "allow_cpu", "keep_epoch_checkpoints"}
}}

# %% [markdown]
# ## 2. Load Prepared Data and Shared Training Pipeline

# %%
data = prepared_namespace()
assert data.config.get("quick_run") == QUICK_RUN, (
    "QUICK_RUN does not match Notebook 1's prepared cache. "
    "Set the same value in both notebooks and rerun Notebook 1 if needed."
)
trainer = NeuralTrainer(data, TRAINING_CONFIG)
print(f"Loaded {len(data.train_frame):,} train and {len(data.validation_frame):,} validation rows")
print(f"Training batches per epoch: {len(trainer.train_loader)}")
# Out:
# Device: cuda | mixed precision: True | run fingerprint: 5f507c7bb57f
# Loaded 30,260 train and 7,566 validation rows
# Training batches per epoch: 237

# %% [markdown]
# ## 3. Train DenseNet-121

# %%
def build_model():
    model = densenet121(weights=None)
    in_features = model.classifier.in_features
    model.classifier = nn.Sequential(
        nn.Dropout(MODEL_CONFIG["classifier_dropout"]),
        nn.Linear(in_features, data.n_classes),
    )
    return model

densenet, history, logits = trainer.train_or_restore(
    "densenet121", build_model, "DenseNet-121", MODEL_CONFIG
)
predictions = logits.argmax(axis=1)
display(result_frame(data.y_val, predictions, logits, "DenseNet-121"))
trainer.plot_history(history, "DenseNet-121 training")
# Out:
# DenseNet-121: /content/drive/MyDrive/Machine-Learning-Assignment-2/models/task2/checkpoints/model_densenet121.pt has an incompatible model configuration; training a compatible checkpoint
# Training class weights: {'Fall': np.float64(0.729), 'Spring': np.float64(1.87), 'Summer': np.float64(0.54), 'Winter': np.float64(0.861)}
# [DenseNet-121] starting epoch 1/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 1/30 | train loss 1.1921 | val loss 1.0114 | train accuracy 0.5116 | val accuracy 0.5870 | macro-F1 0.5505 | best 0.5505 (epoch 1) | lr 5.00e-04 | 557s
# [DenseNet-121] starting epoch 2/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 2/30 | train loss 1.0852 | val loss 0.9465 | train accuracy 0.5770 | val accuracy 0.6318 | macro-F1 0.5906 | best 0.5906 (epoch 2) | lr 7.50e-04 | 557s
# [DenseNet-121] starting epoch 3/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 3/30 | train loss 1.0240 | val loss 0.9245 | train accuracy 0.6150 | val accuracy 0.6167 | macro-F1 0.5923 | best 0.5923 (epoch 3) | lr 1.00e-03 | 557s
# [DenseNet-121] starting epoch 4/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 4/30 | train loss 1.0022 | val loss 0.8796 | train accuracy 0.6276 | val accuracy 0.6353 | macro-F1 0.6426 | best 0.6426 (epoch 4) | lr 1.00e-03 | 557s
# [DenseNet-121] starting epoch 5/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 5/30 | train loss 0.9682 | val loss 0.8620 | train accuracy 0.6476 | val accuracy 0.6771 | macro-F1 0.6665 | best 0.6665 (epoch 5) | lr 9.96e-04 | 558s
# [DenseNet-121] starting epoch 6/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 6/30 | train loss 0.9509 | val loss 0.8315 | train accuracy 0.6623 | val accuracy 0.6808 | macro-F1 0.6793 | best 0.6793 (epoch 6) | lr 9.85e-04 | 558s
# [DenseNet-121] starting epoch 7/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 7/30 | train loss 0.9368 | val loss 0.9150 | train accuracy 0.6657 | val accuracy 0.6409 | macro-F1 0.6540 | best 0.6793 (epoch 6) | lr 9.68e-04 | 557s
# [DenseNet-121] starting epoch 8/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 8/30 | train loss 0.9214 | val loss 0.8627 | train accuracy 0.6739 | val accuracy 0.6599 | macro-F1 0.6775 | best 0.6793 (epoch 6) | lr 9.43e-04 | 557s
# [DenseNet-121] starting epoch 9/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 9/30 | train loss 0.9120 | val loss 0.8425 | train accuracy 0.6814 | val accuracy 0.6938 | macro-F1 0.6702 | best 0.6793 (epoch 6) | lr 9.11e-04 | 556s
# [DenseNet-121] starting epoch 10/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 10/30 | train loss 0.8996 | val loss 0.8482 | train accuracy 0.6862 | val accuracy 0.6934 | macro-F1 0.6847 | best 0.6847 (epoch 10) | lr 8.74e-04 | 557s
# [DenseNet-121] starting epoch 11/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 11/30 | train loss 0.8874 | val loss 0.8317 | train accuracy 0.6932 | val accuracy 0.7059 | macro-F1 0.6812 | best 0.6847 (epoch 10) | lr 8.32e-04 | 557s
# [DenseNet-121] starting epoch 12/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 12/30 | train loss 0.8817 | val loss 0.8258 | train accuracy 0.6974 | val accuracy 0.6856 | macro-F1 0.6813 | best 0.6847 (epoch 10) | lr 7.84e-04 | 557s
# [DenseNet-121] starting epoch 13/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 13/30 | train loss 0.8676 | val loss 0.8113 | train accuracy 0.7082 | val accuracy 0.7001 | macro-F1 0.6853 | best 0.6853 (epoch 13) | lr 7.32e-04 | 557s
# [DenseNet-121] starting epoch 14/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 14/30 | train loss 0.8634 | val loss 0.8437 | train accuracy 0.7071 | val accuracy 0.6716 | macro-F1 0.6801 | best 0.6853 (epoch 13) | lr 6.77e-04 | 556s
# [DenseNet-121] starting epoch 15/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 15/30 | train loss 0.8504 | val loss 0.8332 | train accuracy 0.7157 | val accuracy 0.6791 | macro-F1 0.6816 | best 0.6853 (epoch 13) | lr 6.20e-04 | 557s
# [DenseNet-121] starting epoch 16/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 16/30 | train loss 0.8387 | val loss 0.8279 | train accuracy 0.7204 | val accuracy 0.6916 | macro-F1 0.6900 | best 0.6900 (epoch 16) | lr 5.60e-04 | 558s
# [DenseNet-121] starting epoch 17/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 17/30 | train loss 0.8305 | val loss 0.8009 | train accuracy 0.7268 | val accuracy 0.7055 | macro-F1 0.6973 | best 0.6973 (epoch 17) | lr 5.00e-04 | 557s
# [DenseNet-121] starting epoch 18/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 18/30 | train loss 0.8172 | val loss 0.7981 | train accuracy 0.7308 | val accuracy 0.6914 | macro-F1 0.7038 | best 0.7038 (epoch 18) | lr 4.40e-04 | 557s
# [DenseNet-121] starting epoch 19/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 19/30 | train loss 0.8106 | val loss 0.7997 | train accuracy 0.7357 | val accuracy 0.7095 | macro-F1 0.7002 | best 0.7038 (epoch 18) | lr 3.80e-04 | 557s
# [DenseNet-121] starting epoch 20/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 20/30 | train loss 0.7981 | val loss 0.7796 | train accuracy 0.7427 | val accuracy 0.7198 | macro-F1 0.7126 | best 0.7126 (epoch 20) | lr 3.23e-04 | 556s
# [DenseNet-121] starting epoch 21/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 21/30 | train loss 0.7809 | val loss 0.7610 | train accuracy 0.7498 | val accuracy 0.7268 | macro-F1 0.7187 | best 0.7187 (epoch 21) | lr 2.68e-04 | 557s
# [DenseNet-121] starting epoch 22/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 22/30 | train loss 0.7657 | val loss 0.7678 | train accuracy 0.7576 | val accuracy 0.7283 | macro-F1 0.7265 | best 0.7265 (epoch 22) | lr 2.16e-04 | 558s
# [DenseNet-121] starting epoch 23/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 23/30 | train loss 0.7527 | val loss 0.7817 | train accuracy 0.7655 | val accuracy 0.7136 | macro-F1 0.6979 | best 0.7265 (epoch 22) | lr 1.68e-04 | 557s
# [DenseNet-121] starting epoch 24/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 24/30 | train loss 0.7344 | val loss 0.7553 | train accuracy 0.7738 | val accuracy 0.7343 | macro-F1 0.7325 | best 0.7325 (epoch 24) | lr 1.26e-04 | 556s
# [DenseNet-121] starting epoch 25/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 25/30 | train loss 0.7212 | val loss 0.7537 | train accuracy 0.7786 | val accuracy 0.7420 | macro-F1 0.7373 | best 0.7373 (epoch 25) | lr 8.85e-05 | 556s
# [DenseNet-121] starting epoch 26/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 26/30 | train loss 0.7042 | val loss 0.7527 | train accuracy 0.7872 | val accuracy 0.7446 | macro-F1 0.7321 | best 0.7373 (epoch 25) | lr 5.73e-05 | 557s
# [DenseNet-121] starting epoch 27/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 27/30 | train loss 0.6912 | val loss 0.7690 | train accuracy 0.7942 | val accuracy 0.7296 | macro-F1 0.7190 | best 0.7373 (epoch 25) | lr 3.25e-05 | 557s
# [DenseNet-121] starting epoch 28/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 28/30 | train loss 0.6786 | val loss 0.7563 | train accuracy 0.8047 | val accuracy 0.7390 | macro-F1 0.7285 | best 0.7373 (epoch 25) | lr 1.45e-05 | 556s
# [DenseNet-121] starting epoch 29/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 29/30 | train loss 0.6718 | val loss 0.7589 | train accuracy 0.8072 | val accuracy 0.7405 | macro-F1 0.7309 | best 0.7373 (epoch 25) | lr 3.65e-06 | 557s
# [DenseNet-121] starting epoch 30/30 (237 train + 15 validation batches)
# [DenseNet-121] finished epoch 30/30 | train loss 0.6655 | val loss 0.7537 | train accuracy 0.8085 | val accuracy 0.7423 | macro-F1 0.7324 | best 0.7373 (epoch 25) | lr 0.00e+00 | 557s
# [DenseNet-121] early stopping after epoch 30; no macro-F1 improvement for 5 epochs
# DenseNet-121: best macro-F1 0.7373 in 16727s
#           Model  Top-1 accuracy  Macro-F1  Balanced accuracy  Weighted F1  \
# 0  DenseNet-121        0.742004  0.737306           0.728526     0.741683
#
#    Top-2 accuracy
# 0        0.926513

# %% [markdown]
# ## 4. Export DenseNet-121 Results

# %%
print("Completed checkpoint:", model_checkpoint_path("densenet121"))
print("Run fingerprint:", data.fingerprint)
# Out:
# Completed checkpoint: /content/drive/MyDrive/Machine-Learning-Assignment-2/models/task2/checkpoints/model_densenet121.pt
# Run fingerprint: 5f507c7bb57f
